# %%
a = 1
b = 2
a + b

# %%
import math
math.sqrt(16)

# %% [markdown]
# ## Example Notebook
# This notebook contains code cells with metadata:
# - `editable: false`
# - `deletable: false`
# - `jupyter.source_hidden: true`
#
# So the code is hidden and cannot be uncollapsed in JupyterLab.
